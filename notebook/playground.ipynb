# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data loading

# %%
train_path = '../data/train.csv'
test_path = '../data/test_for_submission.csv'
sample_path = '../data/sample_submission.csv'

# %%
df = pd.read_csv(train_path)
